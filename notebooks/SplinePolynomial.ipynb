# %%
xarray=[0,1,2,3,4,5,6]
yarray=[2.5,0.5,0.5,2,2,1.5,0]
myData = list(zip(xarray, yarray))

# %%
myData
# Out:
# [(0, 2.50000000000000),
#  (1, 0.500000000000000),
#  (2, 0.500000000000000),
#  (3, 2),
#  (4, 2),
#  (5, 1.50000000000000),
#  (6, 0)]

# %%
f1 = list_plot(myData, size=50)

# %%
s=spline(myData)

# %%
f2=plot(s,(x,xarray[0],xarray[6]))

# %%
(f1+f2).show()
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
R=PolynomialRing(QQ,'xx')
pol(xx) = R.lagrange_polynomial(myData)
f3=plot(pol(xx),(xx,xarray[0],xarray[6]), color='green', thickness=3, legend_label="polynomial interpolation")

# %%
(f1+f2+f3).show()
# Out:
# Graphics object consisting of 3 graphics primitives
